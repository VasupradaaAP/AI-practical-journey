# %%
class amazon_acc:

    def login(self,n,pw):
        
        if pw == "aar567":
            return f"Welcome {n.capitalize()}. Book your order!"
        else:
            return f"Check your password! Try again."

account = amazon_acc()
account.login("aarav","aar567")
# Out:
# 'Welcome Aarav. Book your order!'

# %%
class amazon_acc:

    def __init__(self, name, pw):
        self.name = name
        self.__pw = pw

    def login(self):
        if self.__pw == "aar567":
            return f"Welcome {self.name.capitalize()}. Book your order !"
        else:
            return f"Check your password! Try again. Your password is {self.pw}"
        

account = amazon_acc("aarav","aar567")
account.login()
# Out:
# 'Welcome Aarav. Book your order !'

# %%
class amazon_acc:

    def __init__(self, name, pw):
        self.name = name
        self.__pw = pw

    def login(self):
        if self.__pw == "aar567":
            return f"Welcome {self.name.capitalize()}. Book your order !"
        else:
            return f"Check your password! Try again. {self.pw}"
        
class cart():
    pass

class book_order():
    pass

class order_received():
    pass

class feedback():
    pass


account = amazon_acc("aarav","aar567")
account.login()
# Out:
# 'Welcome Aarav. Book your order !'
